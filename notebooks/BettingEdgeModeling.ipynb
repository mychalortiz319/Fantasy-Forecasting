# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dfAll = pd.read_csv("/Users/mychalortiz/Downloads/Brainstation/BettingEdge/notebooks/Dataframes/dfAll.csv")
qbs = pd.read_csv("/Users/mychalortiz/Downloads/Brainstation/BettingEdge/notebooks/Dataframes/qbs.csv")
rbs = pd.read_csv("/Users/mychalortiz/Downloads/Brainstation/BettingEdge/notebooks/Dataframes/rbs.csv")
wrs = pd.read_csv("/Users/mychalortiz/Downloads/Brainstation/BettingEdge/notebooks/Dataframes/wrs.csv")
tes = pd.read_csv("/Users/mychalortiz/Downloads/Brainstation/BettingEdge/notebooks/Dataframes/tes.csv")

# %% [markdown]
# - Transferring dataframes from previous notebook to the current notebook

# %%
qbs.head(5)
# Out:
#    Unnamed: 0         PLAYER NAME PLAYER TEAM PLAYER POSITION   STATUS  PROJ  \
# 0           2          Josh Allen         Buf              QB  W 48-20  20.9
# 1           7  Anthony Richardson         Ind              QB  L 23-29  20.2
# 2           8       Lamar Jackson         Bal              QB   W 28-3  17.9
# 3          10       Justin Fields         Chi              QB  L 28-31  20.0
# 4          20         Jalen Hurts         Phi              QB  W 34-31  21.7
#
#    PASSING YDS  PASSING TD  PASSING INT  RUSHING CAR  ...  PASSING COMPLETION  \
# 0        320.0         4.0          0.0          4.0  ...                21.0
# 1        200.0         2.0          0.0         10.0  ...                11.0
# 2        186.0         2.0          0.0          9.0  ...                15.0
# 3        335.0         4.0          1.0          4.0  ...                28.0
# 4        319.0         2.0          0.0          9.0  ...                25.0
#
# ...

# %% [markdown]
# - Ensuring dataframes have been transfered
